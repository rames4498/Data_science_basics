# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame({'year':[2013,2014,2015],'score':[153,225,180],'strate':[145,184,176]})

# %%
df
# Out:
#    year  score  strate
# 0  2013    153     145
# 1  2014    225     184
# 2  2015    180     176

# %%
df['year']
# Out:
# 0    2013
# 1    2014
# 2    2015
# Name: year, dtype: int64

# %%
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
df['score']>500
# Out:
# 0    False
# 1    False
# 2    False
# Name: score, dtype: bool

# %%
plt.plot(df['year'],df['score'])
plt.plot(df['year'],df['strate'])
plt.title('performence')
plt.legend(['score','strikerate'])
plt.show()

# %%
plt.plot(df['year'],df['score'])
plt.plot(df['year'],df['strate'])
plt.title('performence')
plt.legend(['score','strikerate'])
plt.savefig('cricket')
