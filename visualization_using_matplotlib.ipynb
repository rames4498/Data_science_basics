# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4],[9,4,18,8])

# %%
plt.plot([1,2,3,4],[4,2,16,4])
plt.plot([1,2,3,4],[16,4,4,2])
plt.xlabel('x axis')
plt.ylabel('y axis')
#plt.legend takes list as an arguement
plt.legend(['AUS','IND'])
plt.title('graph')
plt.show()

# %%
plt.plot([1,2,3,4],[4,2,16,4])
plt.plot([1,2,3,4],[16,4,4,2])
plt.xlabel('x axis')
plt.ylabel('y axis')
#plt.legend takes list as an arguement
plt.legend(['AUS','IND'])
plt.title('graph')
plt.savefig('visualization')
